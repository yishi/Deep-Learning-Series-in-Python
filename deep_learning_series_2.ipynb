# %% [markdown]
# # Deep Learning Series 2: Classifying MNIST digits using Multi-Layer Perceptron

# %% [markdown]
# ## 1. Introduction
#
# An MLP (for Multi-Layer Perceptron) can be viewed as a logistic regression classifier where the input is first transformed using a learnt non-linear transformation.
#
# This transformation projects the input data into a space where it becomes linearly separable.
#
# This intermediate layer is referred to as a hidden layer.

# %%
from IPython.display import Image

# %%
Image("nnet_1.PNG")

# %% [markdown]
# The activation function has 4 forms as below:

# %%
Image("nnet_2.PNG")

# %% [markdown]
# The multi-layer perceptron:

# %%
Image("nnet_3.PNG")

# %%
Image("nnet_4.PNG")

# %% [markdown]
# We could use error back propagation method to tune weights.

# %%
Image("nnet_5.PNG")

# %% [markdown]
# ## 2. A single hidden layer neural network
#
# An MLP (or Artificial Neural Network - ANN) with a single hidden layer can be represented graphically as follows:

# %%
Image("nnet_6.PNG")

# %%
Image("nnet_7.PNG")

# %% [markdown]
# The hidden layer is:

# %%
Image("nnet_8.PNG")

# %% [markdown]
# Typical choices for **s** include **tanh** or the **logistic sigmoid** function.

# %%
Image("nnet_9.PNG")

# %%
Image("nnet_10.PNG")

# %% [markdown]
# We will be using **tanh** in here because it typically yields to faster training.
#
# To train an MLP, we learn all parameters of the model, and here we use **Stochastic Gradient Descent with minibatches**.
#
# The set of parameters to learn is the set \theta = \{W^{(2)},b^{(2)},W^{(1)},b^{(1)}\}.
#
# The gradients can be achieved through the **back propagation algorithm** (a special case of the chain-rule of derivation).

# %%
import numpy

import theano
import theano.tensor as T

# %%
class HiddenLayer(object):
    def __init__(self, rng, input, n_in, n_out, W=None, b=None,
                 activation=T.tanh):
        """
        Typical hidden layer of a MLP: units are fully-connected and have
        sigmoidal activation function. Weight matrix W is of shape (n_in,n_out)
        and the bias vector b is of shape (n_out,).

        NOTE : The nonlinearity used here is tanh

        Hidden unit activation is given by: tanh(dot(input,W) + b)

        :type rng: numpy.random.RandomState
        :param rng: a random number generator used to initialize weights

        :type input: theano.tensor.dmatrix
        :param input: a symbolic tensor of shape (n_examples, n_in)

        :type n_in: int
        :param n_in: dimensionality of input

        :type n_out: int
        :param n_out: number of hidden units

        :type activation: theano.Op or function
        :param activation: Non linearity to be applied in the hidden
                           layer
        """
        self.input = input
        # `W` is initialized with `W_values` which is uniformely sampled
        # from sqrt(-6./(n_in+n_hidden)) and sqrt(6./(n_in+n_hidden))
        # for tanh activation function
        # the output of uniform if converted using asarray to dtype
        # theano.config.floatX so that the code is runable on GPU
        # Note : optimal initialization of weights is dependent on the
        #        activation function used (among other things).
        #        For example, results presented in [Xavier10] suggest that you
        #        should use 4 times larger initial weights for sigmoid
        #        compared to tanh
        #        We have no info for other function, so we use the same as
        #        tanh.
        if W is None:
            W_values = numpy.asarray(
                rng.uniform(
                    low=-numpy.sqrt(6. / (n_in + n_out)),
                    high=numpy.sqrt(6. / (n_in + n_out)),
                    size=(n_in, n_out)
                ),
                dtype=theano.config.floatX
            )
            if activation == theano.tensor.nnet.sigmoid:
                W_values *= 4

            W = theano.shared(value=W_values, name='W', borrow=True)

        if b is None:
            b_values = numpy.zeros((n_out,), dtype=theano.config.floatX)
            b = theano.shared(value=b_values, name='b', borrow=True)

        self.W = W
        self.b = b
        # parameters of the model
        self.params = [self.W, self.b]
        
        lin_output = T.dot(input, self.W) + self.b
        self.output = (
            lin_output if activation is None
            else activation(lin_output)
        )

# %%
class LogisticRegression(object):
    """Multi-class Logistic Regression Class
    
    The logistic regression is fully described by a weight matrix and 
    bias vector. Classification is done by projecting data points onto
    a set of hyperplanes, the distance to which is used to determine a 
    class membership probability.
    """
    def __init__(self, input, n_in, n_out):
        """Initialize the parameters of the logistic regression
        
        :input: the input of the architecture (one minibatch)
        :n_in: number of input units
        :n_out: number of ouput units
        """
        self.W = theano.shared(value = numpy.zeros((n_in, n_out), dtype = theano.config.floatX),
                               name = 'W', borrow = True)
        self.b = theano.shared(value = numpy.zeros((n_out,), dtype = theano.config.floatX), 
                               name = 'b', borrow = True)
        
        # computing the matrix of class-membership probabilities
        self.p_y_given_x = T.nnet.softmax(T.dot(input, self.W) + self.b)
        
        # how to compute prediction as class whose probability is maximal
        self.y_pred = T.argmax(self.p_y_given_x, axis = 1)
        
        self.params = [self.W, self.b]
        self.input = input
        
    def negative_log_likelihood(self, y):
        """Return the mean of the nagative log-likelihood of the prediction
        of this model under a given target distribution.
        
        Note: we use the mean instead of the sum so that
              the learning rate is less dependent on the batch size
        """
        return -T.mean(T.log(self.p_y_given_x)[T.arange(y.shape[0]), y])
    
    def errors(self, y):
        """Return a float representing the number of errors in the minibatch
        over the total number of examples of the minibatch;
        zero one loss over the size of the minibatch
        """
        # check if y has same dimension of y_pred
        if y.ndim != self.y_pred.ndim:
            raise TypeError(
                 'y should have the same shape as self.y_pred', 
                 ('y', y.type, 'y_pred', self.y_pred.type)
             )
        # check if y is of the correct datatype    
        if y.dtype.startswith('int'):
            return T.mean(T.neq(self.y_pred, y))
        else:
            raise NotImplementedError()

# %%
class MLP(object):
    """Multi-Layer Perceptron Class

    A multilayer perceptron is a feedforward artificial neural network model
    that has one layer or more of hidden units and nonlinear activations.
    Intermediate layers usually have as activation function tanh or the
    sigmoid function (defined here by a ``HiddenLayer`` class)  while the
    top layer is a softmax layer (defined here by a ``LogisticRegression``
    class).
    """

    def __init__(self, rng, input, n_in, n_hidden, n_out):
        """Initialize the parameters for the multilayer perceptron

        :type rng: numpy.random.RandomState
        :param rng: a random number generator used to initialize weights

        :type input: theano.tensor.TensorType
        :param input: symbolic variable that describes the input of the
        architecture (one minibatch)

        :type n_in: int
        :param n_in: number of input units, the dimension of the space in
        which the datapoints lie

        :type n_hidden: int
        :param n_hidden: number of hidden units

        :type n_out: int
        :param n_out: number of output units, the dimension of the space in
        which the labels lie

        """

        # Since we are dealing with a one hidden layer MLP, this will translate
        # into a HiddenLayer with a tanh activation function connected to the
        # LogisticRegression layer; the activation function can be replaced by
        # sigmoid or any other nonlinear function
        self.hiddenLayer = HiddenLayer(
            rng=rng,
            input=input,
            n_in=n_in,
            n_out=n_hidden,
            activation=T.tanh
        )

        # The logistic regression layer gets as input the hidden units
        # of the hidden layer
        self.logRegressionLayer = LogisticRegression(
            input=self.hiddenLayer.output,
            n_in=n_hidden,
            n_out=n_out
        )
        # L1 norm ; one regularization option is to enforce L1 norm to
        # be small
        self.L1 = (
            abs(self.hiddenLayer.W).sum()
            + abs(self.logRegressionLayer.W).sum()
        )

        # square of L2 norm ; one regularization option is to enforce
        # square of L2 norm to be small
        self.L2_sqr = (
            (self.hiddenLayer.W ** 2).sum()
            + (self.logRegressionLayer.W ** 2).sum()
        )

        # negative log likelihood of the MLP is given by the negative
        # log likelihood of the output of the model, computed in the
        # logistic regression layer
        self.negative_log_likelihood = (
            self.logRegressionLayer.negative_log_likelihood
        )
        # same holds for the function computing the number of errors
        self.errors = self.logRegressionLayer.errors

        # the parameters of the model are the parameters of the two layer it is
        # made out of
        self.params = self.hiddenLayer.params + self.logRegressionLayer.params
        
        # keep track of model input
        self.input = input

# %%
def load_data(dataset):
    ''' Loads the dataset

    :type dataset: string
    :param dataset: the path to the dataset (here MNIST)
    '''
    #############
    # LOAD DATA #
    #############

    # Load the dataset
    with gzip.open(dataset, 'rb') as f:
        try:
            train_set, valid_set, test_set = pickle.load(f, encoding='latin1')
        except:
            train_set, valid_set, test_set = pickle.load(f)
    
    def shared_dataset(data_xy, borrow=True):
        """ Function that loads the dataset into shared variables

        The reason we store our dataset in shared variables is to allow
        Theano to copy it into the GPU memory (when code is run on GPU).
        Since copying data into the GPU is slow, copying a minibatch everytime
        is needed (the default behaviour if the data is not in a shared
        variable) would lead to a large decrease in performance.
        """
        data_x, data_y = data_xy
        shared_x = theano.shared(numpy.asarray(data_x,
                                               dtype=theano.config.floatX),
                                 borrow=borrow)
        shared_y = theano.shared(numpy.asarray(data_y,
                                               dtype=theano.config.floatX),
                                 borrow=borrow)
        # When storing data on the GPU it has to be stored as floats
        # therefore we will store the labels as ``floatX`` as well
        # (``shared_y`` does exactly that). But during our computations
        # we need them as ints (we use labels as index, and if they are
        # floats it doesn't make sense) therefore instead of returning
        # ``shared_y`` we will have to cast it to int. This little hack
        # lets ous get around this issue
        return shared_x, T.cast(shared_y, 'int32')

    test_set_x, test_set_y = shared_dataset(test_set)
    valid_set_x, valid_set_y = shared_dataset(valid_set)
    train_set_x, train_set_y = shared_dataset(train_set)

    rval = [(train_set_x, train_set_y), (valid_set_x, valid_set_y),
            (test_set_x, test_set_y)]
    return rval

# %%
def test_mlp(learning_rate=0.01, L1_reg=0.00, L2_reg=0.0001, n_epochs=1000,
             dataset='mnist.pkl.gz', batch_size=20, n_hidden=500):
    """
    Demonstrate stochastic gradient descent optimization for a multilayer
    perceptron

    This is demonstrated on MNIST.

    :type learning_rate: float
    :param learning_rate: learning rate used (factor for the stochastic
    gradient

    :type L1_reg: float
    :param L1_reg: L1-norm's weight when added to the cost (see
    regularization)

    :type L2_reg: float
    :param L2_reg: L2-norm's weight when added to the cost (see
    regularization)

    :type n_epochs: int
    :param n_epochs: maximal number of epochs to run the optimizer

    :type dataset: string
    :param dataset: the path of the MNIST dataset file from
                 http://www.iro.umontreal.ca/~lisa/deep/data/mnist/mnist.pkl.gz


   """
    datasets = load_data(dataset)

    train_set_x, train_set_y = datasets[0]
    valid_set_x, valid_set_y = datasets[1]
    test_set_x, test_set_y = datasets[2]

    # compute number of minibatches for training, validation and testing
    n_train_batches = train_set_x.get_value(borrow=True).shape[0] // batch_size
    n_valid_batches = valid_set_x.get_value(borrow=True).shape[0] // batch_size
    n_test_batches = test_set_x.get_value(borrow=True).shape[0] // batch_size

    ######################
    # BUILD ACTUAL MODEL #
    ######################
    print('... building the model')

    # allocate symbolic variables for the data
    index = T.lscalar()  # index to a [mini]batch
    x = T.matrix('x')  # the data is presented as rasterized images
    y = T.ivector('y')  # the labels are presented as 1D vector of
                        # [int] labels

    rng = numpy.random.RandomState(1234)

    # construct the MLP class
    classifier = MLP(
        rng=rng,
        input=x,
        n_in=28 * 28,
        n_hidden=n_hidden,
        n_out=10
    )

    # start-snippet-4
    # the cost we minimize during training is the negative log likelihood of
    # the model plus the regularization terms (L1 and L2); cost is expressed
    # here symbolically
    cost = (
        classifier.negative_log_likelihood(y)
        + L1_reg * classifier.L1
        + L2_reg * classifier.L2_sqr
    )
    # end-snippet-4

    # compiling a Theano function that computes the mistakes that are made
    # by the model on a minibatch
    test_model = theano.function(
        inputs=[index],
        outputs=classifier.errors(y),
        givens={
            x: test_set_x[index * batch_size:(index + 1) * batch_size],
            y: test_set_y[index * batch_size:(index + 1) * batch_size]
        }
    )

    validate_model = theano.function(
        inputs=[index],
        outputs=classifier.errors(y),
        givens={
            x: valid_set_x[index * batch_size:(index + 1) * batch_size],
            y: valid_set_y[index * batch_size:(index + 1) * batch_size]
        }
    )

    # start-snippet-5
    # compute the gradient of cost with respect to theta (sorted in params)
    # the resulting gradients will be stored in a list gparams
    gparams = [T.grad(cost, param) for param in classifier.params]

    # specify how to update the parameters of the model as a list of
    # (variable, update expression) pairs

    # given two lists of the same length, A = [a1, a2, a3, a4] and
    # B = [b1, b2, b3, b4], zip generates a list C of same size, where each
    # element is a pair formed from the two lists :
    #    C = [(a1, b1), (a2, b2), (a3, b3), (a4, b4)]
    updates = [
        (param, param - learning_rate * gparam)
        for param, gparam in zip(classifier.params, gparams)
    ]

    # compiling a Theano function `train_model` that returns the cost, but
    # in the same time updates the parameter of the model based on the rules
    # defined in `updates`
    train_model = theano.function(
        inputs=[index],
        outputs=cost,
        updates=updates,
        givens={
            x: train_set_x[index * batch_size: (index + 1) * batch_size],
            y: train_set_y[index * batch_size: (index + 1) * batch_size]
        }
    )
    # end-snippet-5

    ###############
    # TRAIN MODEL #
    ###############
    print('... training')

    # early-stopping parameters
    patience = 10000  # look as this many examples regardless
    patience_increase = 2  # wait this much longer when a new best is
                           # found
    improvement_threshold = 0.995  # a relative improvement of this much is
                                   # considered significant
    validation_frequency = min(n_train_batches, patience // 2)
                                  # go through this many
                                  # minibatche before checking the network
                                  # on the validation set; in this case we
                                  # check every epoch

    best_validation_loss = numpy.inf
    best_iter = 0
    test_score = 0.
    start_time = timeit.default_timer()

    epoch = 0
    done_looping = False

    while (epoch < n_epochs) and (not done_looping):
        epoch = epoch + 1
        for minibatch_index in range(n_train_batches):

            minibatch_avg_cost = train_model(minibatch_index)
            # iteration number
            iter = (epoch - 1) * n_train_batches + minibatch_index

            if (iter + 1) % validation_frequency == 0:
                # compute zero-one loss on validation set
                validation_losses = [validate_model(i) for i
                                     in range(n_valid_batches)]
                this_validation_loss = numpy.mean(validation_losses)

                print(
                    'epoch %i, minibatch %i/%i, validation error %f %%' %
                    (
                        epoch,
                        minibatch_index + 1,
                        n_train_batches,
                        this_validation_loss * 100.
                    )
                )

                # if we got the best validation score until now
                if this_validation_loss < best_validation_loss:
                    #improve patience if loss improvement is good enough
                    if (
                        this_validation_loss < best_validation_loss *
                        improvement_threshold
                    ):
                        patience = max(patience, iter * patience_increase)

                    best_validation_loss = this_validation_loss
                    best_iter = iter

                    # test it on the test set
                    test_losses = [test_model(i) for i
                                   in range(n_test_batches)]
                    test_score = numpy.mean(test_losses)

                    print(('     epoch %i, minibatch %i/%i, test error of '
                           'best model %f %%') %
                          (epoch, minibatch_index + 1, n_train_batches,
                           test_score * 100.))

            if patience <= iter:
                done_looping = True
                break

    end_time = timeit.default_timer()
    print(('Optimization complete. Best validation score of %f %% '
           'obtained at iteration %i, with test performance %f %%') %
          (best_validation_loss * 100., best_iter + 1, test_score * 100.))
    print('The code for this function ran for %.2fm' % ((end_time - start_time) / 60.))

# %% [markdown]
# ## 3. Run a single hidden layer neural network

# %%
"""
This code introduces the multilayer perceptron using Theano.

 A multilayer perceptron is a logistic regressor where
instead of feeding the input to the logistic regression you insert a
intermediate layer, called the hidden layer, that has a nonlinear
activation function (usually tanh or sigmoid) . 

One can use many such hidden layers making the architecture deep. 

The tutorial will also tackle the problem of MNIST digit classification.

.. math::

    f(x) = G( b^{(2)} + W^{(2)}( s( b^{(1)} + W^{(1)} x))),

References:

    - textbooks: "Pattern Recognition and Machine Learning" -
                 Christopher M. Bishop, section 5

"""

from __future__ import print_function
import os
import sys
import timeit
import gzip
import six.moves.cPickle as pickle

import numpy

import theano
import theano.tensor as T

# %%
test_mlp()
# Out:
# ... building the model
# ... training
# epoch 1, minibatch 2500/2500, validation error 9.620000 %
#      epoch 1, minibatch 2500/2500, test error of best model 10.090000 %
# epoch 2, minibatch 2500/2500, validation error 8.610000 %
#      epoch 2, minibatch 2500/2500, test error of best model 8.740000 %
# epoch 3, minibatch 2500/2500, validation error 8.000000 %
#      epoch 3, minibatch 2500/2500, test error of best model 8.160000 %
# epoch 4, minibatch 2500/2500, validation error 7.600000 %
#      epoch 4, minibatch 2500/2500, test error of best model 7.790000 %
# epoch 5, minibatch 2500/2500, validation error 7.300000 %
#      epoch 5, minibatch 2500/2500, test error of best model 7.590000 %
# epoch 6, minibatch 2500/2500, validation error 7.020000 %
#      epoch 6, minibatch 2500/2500, test error of best model 7.200000 %
# epoch 7, minibatch 2500/2500, validation error 6.680000 %
#      epoch 7, minibatch 2500/2500, test error of best model 6.990000 %
# epoch 8, minibatch 2500/2500, validation error 6.260000 %
#      epoch 8, minibatch 2500/2500, test error of best model 6.730000 %
# epoch 9, minibatch 2500/2500, validation error 5.970000 %
#      epoch 9, minibatch 2500/2500, test error of best model 6.510000 %
# epoch 10, minibatch 2500/2500, validation error 5.740000 %
#      epoch 10, minibatch 2500/2500, test error of best model 6.190000 %
# epoch 11, minibatch 2500/2500, validation error 5.400000 %
#      epoch 11, minibatch 2500/2500, test error of best model 5.900000 %
# epoch 12, minibatch 2500/2500, validation error 5.080000 %
#      epoch 12, minibatch 2500/2500, test error of best model 5.600000 %
# epoch 13, minibatch 2500/2500, validation error 4.820000 %
#      epoch 13, minibatch 2500/2500, test error of best model 5.400000 %
# epoch 14, minibatch 2500/2500, validation error 4.690000 %
#      epoch 14, minibatch 2500/2500, test error of best model 5.280000 %
# epoch 15, minibatch 2500/2500, validation error 4.470000 %
#      epoch 15, minibatch 2500/2500, test error of best model 5.140000 %
# epoch 16, minibatch 2500/2500, validation error 4.350000 %
#      epoch 16, minibatch 2500/2500, test error of best model 4.890000 %
# epoch 17, minibatch 2500/2500, validation error 4.130000 %
#      epoch 17, minibatch 2500/2500, test error of best model 4.700000 %
# epoch 18, minibatch 2500/2500, validation error 4.040000 %
#      epoch 18, minibatch 2500/2500, test error of best model 4.540000 %
# epoch 19, minibatch 2500/2500, validation error 3.910000 %
#      epoch 19, minibatch 2500/2500, test error of best model 4.420000 %
# epoch 20, minibatch 2500/2500, validation error 3.780000 %
#      epoch 20, minibatch 2500/2500, test error of best model 4.260000 %
# epoch 21, minibatch 2500/2500, validation error 3.700000 %
#      epoch 21, minibatch 2500/2500, test error of best model 4.150000 %
# epoch 22, minibatch 2500/2500, validation error 3.610000 %
#      epoch 22, minibatch 2500/2500, test error of best model 4.000000 %
# epoch 23, minibatch 2500/2500, validation error 3.540000 %
#      epoch 23, minibatch 2500/2500, test error of best model 3.910000 %
# epoch 24, minibatch 2500/2500, validation error 3.480000 %
#      epoch 24, minibatch 2500/2500, test error of best model 3.790000 %
# epoch 25, minibatch 2500/2500, validation error 3.400000 %
#      epoch 25, minibatch 2500/2500, test error of best model 3.710000 %
# epoch 26, minibatch 2500/2500, validation error 3.350000 %
#      epoch 26, minibatch 2500/2500, test error of best model 3.650000 %
# epoch 27, minibatch 2500/2500, validation error 3.260000 %
#      epoch 27, minibatch 2500/2500, test error of best model 3.570000 %
# epoch 28, minibatch 2500/2500, validation error 3.270000 %
# epoch 29, minibatch 2500/2500, validation error 3.240000 %
#      epoch 29, minibatch 2500/2500, test error of best model 3.440000 %
# epoch 30, minibatch 2500/2500, validation error 3.190000 %
#      epoch 30, minibatch 2500/2500, test error of best model 3.370000 %
# epoch 31, minibatch 2500/2500, validation error 3.160000 %
#      epoch 31, minibatch 2500/2500, test error of best model 3.330000 %
# epoch 32, minibatch 2500/2500, validation error 3.090000 %
#      epoch 32, minibatch 2500/2500, test error of best model 3.250000 %
# epoch 33, minibatch 2500/2500, validation error 3.050000 %
#      epoch 33, minibatch 2500/2500, test error of best model 3.170000 %
# epoch 34, minibatch 2500/2500, validation error 3.030000 %
#      epoch 34, minibatch 2500/2500, test error of best model 3.160000 %
# epoch 35, minibatch 2500/2500, validation error 3.020000 %
#      epoch 35, minibatch 2500/2500, test error of best model 3.150000 %
# epoch 36, minibatch 2500/2500, validation error 2.970000 %
#      epoch 36, minibatch 2500/2500, test error of best model 3.090000 %
# epoch 37, minibatch 2500/2500, validation error 2.940000 %
#      epoch 37, minibatch 2500/2500, test error of best model 3.040000 %
# epoch 38, minibatch 2500/2500, validation error 2.910000 %
#      epoch 38, minibatch 2500/2500, test error of best model 3.000000 %
# epoch 39, minibatch 2500/2500, validation error 2.880000 %
#      epoch 39, minibatch 2500/2500, test error of best model 2.980000 %
# epoch 40, minibatch 2500/2500, validation error 2.850000 %
#      epoch 40, minibatch 2500/2500, test error of best model 2.920000 %
# epoch 41, minibatch 2500/2500, validation error 2.810000 %
#      epoch 41, minibatch 2500/2500, test error of best model 2.860000 %
# epoch 42, minibatch 2500/2500, validation error 2.800000 %
#      epoch 42, minibatch 2500/2500, test error of best model 2.840000 %
# epoch 43, minibatch 2500/2500, validation error 2.780000 %
#      epoch 43, minibatch 2500/2500, test error of best model 2.820000 %
# epoch 44, minibatch 2500/2500, validation error 2.760000 %
#      epoch 44, minibatch 2500/2500, test error of best model 2.780000 %
# epoch 45, minibatch 2500/2500, validation error 2.720000 %
#      epoch 45, minibatch 2500/2500, test error of best model 2.730000 %
# epoch 46, minibatch 2500/2500, validation error 2.680000 %
#      epoch 46, minibatch 2500/2500, test error of best model 2.720000 %
# epoch 47, minibatch 2500/2500, validation error 2.630000 %
#      epoch 47, minibatch 2500/2500, test error of best model 2.690000 %
# epoch 48, minibatch 2500/2500, validation error 2.610000 %
#      epoch 48, minibatch 2500/2500, test error of best model 2.690000 %
# epoch 49, minibatch 2500/2500, validation error 2.580000 %
#      epoch 49, minibatch 2500/2500, test error of best model 2.680000 %
# epoch 50, minibatch 2500/2500, validation error 2.560000 %
#      epoch 50, minibatch 2500/2500, test error of best model 2.630000 %
# epoch 51, minibatch 2500/2500, validation error 2.560000 %
# epoch 52, minibatch 2500/2500, validation error 2.510000 %
#      epoch 52, minibatch 2500/2500, test error of best model 2.560000 %
# epoch 53, minibatch 2500/2500, validation error 2.490000 %
#      epoch 53, minibatch 2500/2500, test error of best model 2.530000 %
# epoch 54, minibatch 2500/2500, validation error 2.490000 %
# epoch 55, minibatch 2500/2500, validation error 2.480000 %
#      epoch 55, minibatch 2500/2500, test error of best model 2.520000 %
# epoch 56, minibatch 2500/2500, validation error 2.480000 %
# epoch 57, minibatch 2500/2500, validation error 2.460000 %
#      epoch 57, minibatch 2500/2500, test error of best model 2.500000 %
# epoch 58, minibatch 2500/2500, validation error 2.450000 %
#      epoch 58, minibatch 2500/2500, test error of best model 2.460000 %
# epoch 59, minibatch 2500/2500, validation error 2.430000 %
#      epoch 59, minibatch 2500/2500, test error of best model 2.440000 %
# epoch 60, minibatch 2500/2500, validation error 2.420000 %
#      epoch 60, minibatch 2500/2500, test error of best model 2.450000 %
# epoch 61, minibatch 2500/2500, validation error 2.390000 %
#      epoch 61, minibatch 2500/2500, test error of best model 2.410000 %
# epoch 62, minibatch 2500/2500, validation error 2.400000 %
# epoch 63, minibatch 2500/2500, validation error 2.400000 %
# epoch 64, minibatch 2500/2500, validation error 2.400000 %
# epoch 65, minibatch 2500/2500, validation error 2.350000 %
#      epoch 65, minibatch 2500/2500, test error of best model 2.350000 %
# epoch 66, minibatch 2500/2500, validation error 2.350000 %
# epoch 67, minibatch 2500/2500, validation error 2.320000 %
#      epoch 67, minibatch 2500/2500, test error of best model 2.350000 %
# epoch 68, minibatch 2500/2500, validation error 2.320000 %
# epoch 69, minibatch 2500/2500, validation error 2.320000 %
# epoch 70, minibatch 2500/2500, validation error 2.300000 %
#      epoch 70, minibatch 2500/2500, test error of best model 2.330000 %
# epoch 71, minibatch 2500/2500, validation error 2.290000 %
#      epoch 71, minibatch 2500/2500, test error of best model 2.330000 %
# epoch 72, minibatch 2500/2500, validation error 2.280000 %
#      epoch 72, minibatch 2500/2500, test error of best model 2.300000 %
# epoch 73, minibatch 2500/2500, validation error 2.260000 %
#      epoch 73, minibatch 2500/2500, test error of best model 2.300000 %
# epoch 74, minibatch 2500/2500, validation error 2.250000 %
#      epoch 74, minibatch 2500/2500, test error of best model 2.300000 %
# epoch 75, minibatch 2500/2500, validation error 2.230000 %
#      epoch 75, minibatch 2500/2500, test error of best model 2.300000 %
# epoch 76, minibatch 2500/2500, validation error 2.230000 %
# epoch 77, minibatch 2500/2500, validation error 2.240000 %
# epoch 78, minibatch 2500/2500, validation error 2.250000 %
# epoch 79, minibatch 2500/2500, validation error 2.220000 %
#      epoch 79, minibatch 2500/2500, test error of best model 2.290000 %
# epoch 80, minibatch 2500/2500, validation error 2.210000 %
#      epoch 80, minibatch 2500/2500, test error of best model 2.260000 %
# epoch 81, minibatch 2500/2500, validation error 2.200000 %
#      epoch 81, minibatch 2500/2500, test error of best model 2.250000 %
# epoch 82, minibatch 2500/2500, validation error 2.190000 %
#      epoch 82, minibatch 2500/2500, test error of best model 2.240000 %
# epoch 83, minibatch 2500/2500, validation error 2.190000 %
# epoch 84, minibatch 2500/2500, validation error 2.190000 %
# epoch 85, minibatch 2500/2500, validation error 2.180000 %
#      epoch 85, minibatch 2500/2500, test error of best model 2.220000 %
# epoch 86, minibatch 2500/2500, validation error 2.180000 %
# epoch 87, minibatch 2500/2500, validation error 2.160000 %
#      epoch 87, minibatch 2500/2500, test error of best model 2.220000 %
# epoch 88, minibatch 2500/2500, validation error 2.150000 %
#      epoch 88, minibatch 2500/2500, test error of best model 2.230000 %
# epoch 89, minibatch 2500/2500, validation error 2.150000 %
# epoch 90, minibatch 2500/2500, validation error 2.160000 %
# epoch 91, minibatch 2500/2500, validation error 2.160000 %
# epoch 92, minibatch 2500/2500, validation error 2.170000 %
# epoch 93, minibatch 2500/2500, validation error 2.160000 %
# epoch 94, minibatch 2500/2500, validation error 2.160000 %
# epoch 95, minibatch 2500/2500, validation error 2.150000 %
# epoch 96, minibatch 2500/2500, validation error 2.150000 %
# epoch 97, minibatch 2500/2500, validation error 2.150000 %
# epoch 98, minibatch 2500/2500, validation error 2.140000 %
#      epoch 98, minibatch 2500/2500, test error of best model 2.190000 %
# epoch 99, minibatch 2500/2500, validation error 2.140000 %
# epoch 100, minibatch 2500/2500, validation error 2.130000 %
#      epoch 100, minibatch 2500/2500, test error of best model 2.180000 %
# epoch 101, minibatch 2500/2500, validation error 2.130000 %
# epoch 102, minibatch 2500/2500, validation error 2.130000 %
# epoch 103, minibatch 2500/2500, validation error 2.130000 %
# epoch 104, minibatch 2500/2500, validation error 2.120000 %
#      epoch 104, minibatch 2500/2500, test error of best model 2.170000 %
# epoch 105, minibatch 2500/2500, validation error 2.120000 %
# epoch 106, minibatch 2500/2500, validation error 2.130000 %
# epoch 107, minibatch 2500/2500, validation error 2.130000 %
# epoch 108, minibatch 2500/2500, validation error 2.130000 %
# epoch 109, minibatch 2500/2500, validation error 2.130000 %
# epoch 110, minibatch 2500/2500, validation error 2.130000 %
# epoch 111, minibatch 2500/2500, validation error 2.130000 %
# epoch 112, minibatch 2500/2500, validation error 2.130000 %
# epoch 113, minibatch 2500/2500, validation error 2.120000 %
# epoch 114, minibatch 2500/2500, validation error 2.110000 %
#      epoch 114, minibatch 2500/2500, test error of best model 2.130000 %
# epoch 115, minibatch 2500/2500, validation error 2.100000 %
#      epoch 115, minibatch 2500/2500, test error of best model 2.130000 %
# epoch 116, minibatch 2500/2500, validation error 2.100000 %
# epoch 117, minibatch 2500/2500, validation error 2.100000 %
# epoch 118, minibatch 2500/2500, validation error 2.090000 %
#      epoch 118, minibatch 2500/2500, test error of best model 2.120000 %
# epoch 119, minibatch 2500/2500, validation error 2.080000 %
#      epoch 119, minibatch 2500/2500, test error of best model 2.110000 %
# epoch 120, minibatch 2500/2500, validation error 2.060000 %
#      epoch 120, minibatch 2500/2500, test error of best model 2.120000 %
# epoch 121, minibatch 2500/2500, validation error 2.060000 %
# epoch 122, minibatch 2500/2500, validation error 2.060000 %
# epoch 123, minibatch 2500/2500, validation error 2.060000 %
# epoch 124, minibatch 2500/2500, validation error 2.040000 %
#      epoch 124, minibatch 2500/2500, test error of best model 2.120000 %
# epoch 125, minibatch 2500/2500, validation error 2.060000 %
# epoch 126, minibatch 2500/2500, validation error 2.060000 %
# epoch 127, minibatch 2500/2500, validation error 2.060000 %
# epoch 128, minibatch 2500/2500, validation error 2.040000 %
# epoch 129, minibatch 2500/2500, validation error 2.040000 %
# epoch 130, minibatch 2500/2500, validation error 2.030000 %
#      epoch 130, minibatch 2500/2500, test error of best model 2.090000 %
# epoch 131, minibatch 2500/2500, validation error 2.030000 %
# epoch 132, minibatch 2500/2500, validation error 2.030000 %
# epoch 133, minibatch 2500/2500, validation error 2.040000 %
# epoch 134, minibatch 2500/2500, validation error 2.040000 %
# epoch 135, minibatch 2500/2500, validation error 2.040000 %
# epoch 136, minibatch 2500/2500, validation error 2.040000 %
# epoch 137, minibatch 2500/2500, validation error 2.040000 %
# epoch 138, minibatch 2500/2500, validation error 2.040000 %
# epoch 139, minibatch 2500/2500, validation error 2.050000 %
# epoch 140, minibatch 2500/2500, validation error 2.050000 %
# epoch 141, minibatch 2500/2500, validation error 2.050000 %
# epoch 142, minibatch 2500/2500, validation error 2.050000 %
# epoch 143, minibatch 2500/2500, validation error 2.050000 %
# epoch 144, minibatch 2500/2500, validation error 2.050000 %
# epoch 145, minibatch 2500/2500, validation error 2.050000 %
# epoch 146, minibatch 2500/2500, validation error 2.060000 %
# epoch 147, minibatch 2500/2500, validation error 2.060000 %
# epoch 148, minibatch 2500/2500, validation error 2.050000 %
# epoch 149, minibatch 2500/2500, validation error 2.030000 %
# epoch 150, minibatch 2500/2500, validation error 2.030000 %
# epoch 151, minibatch 2500/2500, validation error 2.030000 %
# epoch 152, minibatch 2500/2500, validation error 2.030000 %
# epoch 153, minibatch 2500/2500, validation error 2.030000 %
# epoch 154, minibatch 2500/2500, validation error 2.030000 %
# epoch 155, minibatch 2500/2500, validation error 2.030000 %
# epoch 156, minibatch 2500/2500, validation error 2.050000 %
# epoch 157, minibatch 2500/2500, validation error 2.050000 %
# epoch 158, minibatch 2500/2500, validation error 2.060000 %
# epoch 159, minibatch 2500/2500, validation error 2.060000 %
# epoch 160, minibatch 2500/2500, validation error 2.050000 %
# epoch 161, minibatch 2500/2500, validation error 2.050000 %
# epoch 162, minibatch 2500/2500, validation error 2.050000 %
# epoch 163, minibatch 2500/2500, validation error 2.050000 %
# epoch 164, minibatch 2500/2500, validation error 2.050000 %
# epoch 165, minibatch 2500/2500, validation error 2.050000 %
# epoch 166, minibatch 2500/2500, validation error 2.050000 %
# epoch 167, minibatch 2500/2500, validation error 2.050000 %
# epoch 168, minibatch 2500/2500, validation error 2.050000 %
# epoch 169, minibatch 2500/2500, validation error 2.050000 %
# epoch 170, minibatch 2500/2500, validation error 2.050000 %
# epoch 171, minibatch 2500/2500, validation error 2.050000 %
# epoch 172, minibatch 2500/2500, validation error 2.050000 %
# epoch 173, minibatch 2500/2500, validation error 2.050000 %
# epoch 174, minibatch 2500/2500, validation error 2.040000 %
# epoch 175, minibatch 2500/2500, validation error 2.040000 %
# epoch 176, minibatch 2500/2500, validation error 2.040000 %
# epoch 177, minibatch 2500/2500, validation error 2.040000 %
# epoch 178, minibatch 2500/2500, validation error 2.040000 %
# epoch 179, minibatch 2500/2500, validation error 2.040000 %
# epoch 180, minibatch 2500/2500, validation error 2.040000 %
# epoch 181, minibatch 2500/2500, validation error 2.040000 %
# epoch 182, minibatch 2500/2500, validation error 2.040000 %
# epoch 183, minibatch 2500/2500, validation error 2.040000 %
# epoch 184, minibatch 2500/2500, validation error 2.040000 %
# epoch 185, minibatch 2500/2500, validation error 2.020000 %
#      epoch 185, minibatch 2500/2500, test error of best model 2.000000 %
# epoch 186, minibatch 2500/2500, validation error 2.010000 %
#      epoch 186, minibatch 2500/2500, test error of best model 1.990000 %
# epoch 187, minibatch 2500/2500, validation error 2.010000 %
# epoch 188, minibatch 2500/2500, validation error 2.010000 %
# epoch 189, minibatch 2500/2500, validation error 2.000000 %
#      epoch 189, minibatch 2500/2500, test error of best model 1.980000 %
# epoch 190, minibatch 2500/2500, validation error 2.000000 %
# epoch 191, minibatch 2500/2500, validation error 2.000000 %
# epoch 192, minibatch 2500/2500, validation error 2.000000 %
# epoch 193, minibatch 2500/2500, validation error 2.000000 %
# epoch 194, minibatch 2500/2500, validation error 2.000000 %
# epoch 195, minibatch 2500/2500, validation error 2.000000 %
# epoch 196, minibatch 2500/2500, validation error 2.000000 %
# epoch 197, minibatch 2500/2500, validation error 2.000000 %
# epoch 198, minibatch 2500/2500, validation error 2.000000 %
# epoch 199, minibatch 2500/2500, validation error 2.000000 %
# epoch 200, minibatch 2500/2500, validation error 2.000000 %
# epoch 201, minibatch 2500/2500, validation error 2.000000 %
# epoch 202, minibatch 2500/2500, validation error 2.000000 %
# epoch 203, minibatch 2500/2500, validation error 1.990000 %
#      epoch 203, minibatch 2500/2500, test error of best model 1.970000 %
# epoch 204, minibatch 2500/2500, validation error 1.990000 %
# epoch 205, minibatch 2500/2500, validation error 1.980000 %
#      epoch 205, minibatch 2500/2500, test error of best model 1.960000 %
# epoch 206, minibatch 2500/2500, validation error 1.980000 %
# epoch 207, minibatch 2500/2500, validation error 1.980000 %
# epoch 208, minibatch 2500/2500, validation error 1.980000 %
# epoch 209, minibatch 2500/2500, validation error 1.980000 %
# epoch 210, minibatch 2500/2500, validation error 1.980000 %
# epoch 211, minibatch 2500/2500, validation error 1.980000 %
# epoch 212, minibatch 2500/2500, validation error 1.980000 %
# epoch 213, minibatch 2500/2500, validation error 1.980000 %
# epoch 214, minibatch 2500/2500, validation error 1.980000 %
# epoch 215, minibatch 2500/2500, validation error 1.980000 %
# epoch 216, minibatch 2500/2500, validation error 1.980000 %
# epoch 217, minibatch 2500/2500, validation error 1.980000 %
# epoch 218, minibatch 2500/2500, validation error 1.980000 %
# epoch 219, minibatch 2500/2500, validation error 1.980000 %
# epoch 220, minibatch 2500/2500, validation error 1.970000 %
#      epoch 220, minibatch 2500/2500, test error of best model 1.940000 %
# epoch 221, minibatch 2500/2500, validation error 1.970000 %
# epoch 222, minibatch 2500/2500, validation error 1.970000 %
# epoch 223, minibatch 2500/2500, validation error 1.970000 %
# epoch 224, minibatch 2500/2500, validation error 1.970000 %
# epoch 225, minibatch 2500/2500, validation error 1.960000 %
#      epoch 225, minibatch 2500/2500, test error of best model 1.950000 %
# epoch 226, minibatch 2500/2500, validation error 1.960000 %
# epoch 227, minibatch 2500/2500, validation error 1.960000 %
# epoch 228, minibatch 2500/2500, validation error 1.950000 %
#      epoch 228, minibatch 2500/2500, test error of best model 1.960000 %
# epoch 229, minibatch 2500/2500, validation error 1.960000 %
# epoch 230, minibatch 2500/2500, validation error 1.960000 %
# epoch 231, minibatch 2500/2500, validation error 1.960000 %
# epoch 232, minibatch 2500/2500, validation error 1.960000 %
# epoch 233, minibatch 2500/2500, validation error 1.960000 %
# epoch 234, minibatch 2500/2500, validation error 1.960000 %
# epoch 235, minibatch 2500/2500, validation error 1.970000 %
# epoch 236, minibatch 2500/2500, validation error 1.970000 %
# epoch 237, minibatch 2500/2500, validation error 1.970000 %
# epoch 238, minibatch 2500/2500, validation error 1.970000 %
# epoch 239, minibatch 2500/2500, validation error 1.970000 %
# epoch 240, minibatch 2500/2500, validation error 1.970000 %
# epoch 241, minibatch 2500/2500, validation error 1.970000 %
# epoch 242, minibatch 2500/2500, validation error 1.970000 %
# epoch 243, minibatch 2500/2500, validation error 1.970000 %
# epoch 244, minibatch 2500/2500, validation error 1.970000 %
# epoch 245, minibatch 2500/2500, validation error 1.970000 %
# epoch 246, minibatch 2500/2500, validation error 1.970000 %
# epoch 247, minibatch 2500/2500, validation error 1.970000 %
# epoch 248, minibatch 2500/2500, validation error 1.970000 %
# epoch 249, minibatch 2500/2500, validation error 1.970000 %
# epoch 250, minibatch 2500/2500, validation error 1.980000 %
# epoch 251, minibatch 2500/2500, validation error 1.980000 %
# epoch 252, minibatch 2500/2500, validation error 1.980000 %
# epoch 253, minibatch 2500/2500, validation error 1.990000 %
# epoch 254, minibatch 2500/2500, validation error 1.990000 %
# epoch 255, minibatch 2500/2500, validation error 1.990000 %
# epoch 256, minibatch 2500/2500, validation error 1.990000 %
# epoch 257, minibatch 2500/2500, validation error 1.970000 %
# epoch 258, minibatch 2500/2500, validation error 1.970000 %
# epoch 259, minibatch 2500/2500, validation error 1.950000 %
# epoch 260, minibatch 2500/2500, validation error 1.950000 %
# epoch 261, minibatch 2500/2500, validation error 1.950000 %
# epoch 262, minibatch 2500/2500, validation error 1.950000 %
# epoch 263, minibatch 2500/2500, validation error 1.950000 %
# epoch 264, minibatch 2500/2500, validation error 1.950000 %
# epoch 265, minibatch 2500/2500, validation error 1.950000 %
# epoch 266, minibatch 2500/2500, validation error 1.950000 %
# epoch 267, minibatch 2500/2500, validation error 1.950000 %
# epoch 268, minibatch 2500/2500, validation error 1.950000 %
# epoch 269, minibatch 2500/2500, validation error 1.950000 %
# epoch 270, minibatch 2500/2500, validation error 1.950000 %
# epoch 271, minibatch 2500/2500, validation error 1.950000 %
# epoch 272, minibatch 2500/2500, validation error 1.950000 %
# epoch 273, minibatch 2500/2500, validation error 1.950000 %
# epoch 274, minibatch 2500/2500, validation error 1.950000 %
# epoch 275, minibatch 2500/2500, validation error 1.950000 %
# epoch 276, minibatch 2500/2500, validation error 1.950000 %
# epoch 277, minibatch 2500/2500, validation error 1.950000 %
# epoch 278, minibatch 2500/2500, validation error 1.950000 %
# epoch 279, minibatch 2500/2500, validation error 1.950000 %
# epoch 280, minibatch 2500/2500, validation error 1.950000 %
# epoch 281, minibatch 2500/2500, validation error 1.940000 %
#      epoch 281, minibatch 2500/2500, test error of best model 1.880000 %
# epoch 282, minibatch 2500/2500, validation error 1.940000 %
# epoch 283, minibatch 2500/2500, validation error 1.940000 %
# epoch 284, minibatch 2500/2500, validation error 1.940000 %
# epoch 285, minibatch 2500/2500, validation error 1.940000 %
# epoch 286, minibatch 2500/2500, validation error 1.940000 %
# epoch 287, minibatch 2500/2500, validation error 1.940000 %
# epoch 288, minibatch 2500/2500, validation error 1.940000 %
# epoch 289, minibatch 2500/2500, validation error 1.940000 %
# epoch 290, minibatch 2500/2500, validation error 1.940000 %
# epoch 291, minibatch 2500/2500, validation error 1.930000 %
#      epoch 291, minibatch 2500/2500, test error of best model 1.850000 %
# epoch 292, minibatch 2500/2500, validation error 1.930000 %
# epoch 293, minibatch 2500/2500, validation error 1.920000 %
#      epoch 293, minibatch 2500/2500, test error of best model 1.840000 %
# epoch 294, minibatch 2500/2500, validation error 1.920000 %
# epoch 295, minibatch 2500/2500, validation error 1.920000 %
# epoch 296, minibatch 2500/2500, validation error 1.920000 %
# epoch 297, minibatch 2500/2500, validation error 1.920000 %
# epoch 298, minibatch 2500/2500, validation error 1.910000 %
#      epoch 298, minibatch 2500/2500, test error of best model 1.830000 %
# epoch 299, minibatch 2500/2500, validation error 1.910000 %
# epoch 300, minibatch 2500/2500, validation error 1.910000 %
# epoch 301, minibatch 2500/2500, validation error 1.910000 %
# epoch 302, minibatch 2500/2500, validation error 1.910000 %
# epoch 303, minibatch 2500/2500, validation error 1.910000 %
# epoch 304, minibatch 2500/2500, validation error 1.900000 %
#      epoch 304, minibatch 2500/2500, test error of best model 1.830000 %
# epoch 305, minibatch 2500/2500, validation error 1.900000 %
# epoch 306, minibatch 2500/2500, validation error 1.890000 %
#      epoch 306, minibatch 2500/2500, test error of best model 1.820000 %
# epoch 307, minibatch 2500/2500, validation error 1.890000 %
# epoch 308, minibatch 2500/2500, validation error 1.890000 %
# epoch 309, minibatch 2500/2500, validation error 1.890000 %
# epoch 310, minibatch 2500/2500, validation error 1.890000 %
# epoch 311, minibatch 2500/2500, validation error 1.890000 %
# epoch 312, minibatch 2500/2500, validation error 1.890000 %
# epoch 313, minibatch 2500/2500, validation error 1.890000 %
# epoch 314, minibatch 2500/2500, validation error 1.890000 %
# epoch 315, minibatch 2500/2500, validation error 1.890000 %
# epoch 316, minibatch 2500/2500, validation error 1.890000 %
# epoch 317, minibatch 2500/2500, validation error 1.890000 %
# epoch 318, minibatch 2500/2500, validation error 1.890000 %
# epoch 319, minibatch 2500/2500, validation error 1.890000 %
# epoch 320, minibatch 2500/2500, validation error 1.890000 %
# epoch 321, minibatch 2500/2500, validation error 1.890000 %
# epoch 322, minibatch 2500/2500, validation error 1.890000 %
# epoch 323, minibatch 2500/2500, validation error 1.890000 %
# epoch 324, minibatch 2500/2500, validation error 1.890000 %
# epoch 325, minibatch 2500/2500, validation error 1.890000 %
# epoch 326, minibatch 2500/2500, validation error 1.890000 %
# epoch 327, minibatch 2500/2500, validation error 1.890000 %
# epoch 328, minibatch 2500/2500, validation error 1.890000 %
# epoch 329, minibatch 2500/2500, validation error 1.890000 %
# epoch 330, minibatch 2500/2500, validation error 1.890000 %
# epoch 331, minibatch 2500/2500, validation error 1.890000 %
# epoch 332, minibatch 2500/2500, validation error 1.890000 %
# epoch 333, minibatch 2500/2500, validation error 1.890000 %
# epoch 334, minibatch 2500/2500, validation error 1.890000 %
# epoch 335, minibatch 2500/2500, validation error 1.890000 %
# epoch 336, minibatch 2500/2500, validation error 1.890000 %
# epoch 337, minibatch 2500/2500, validation error 1.890000 %
# epoch 338, minibatch 2500/2500, validation error 1.890000 %
# epoch 339, minibatch 2500/2500, validation error 1.890000 %
# epoch 340, minibatch 2500/2500, validation error 1.890000 %
# epoch 341, minibatch 2500/2500, validation error 1.890000 %
# epoch 342, minibatch 2500/2500, validation error 1.890000 %
# epoch 343, minibatch 2500/2500, validation error 1.890000 %
# epoch 344, minibatch 2500/2500, validation error 1.890000 %
# epoch 345, minibatch 2500/2500, validation error 1.880000 %
#      epoch 345, minibatch 2500/2500, test error of best model 1.810000 %
# epoch 346, minibatch 2500/2500, validation error 1.880000 %
# epoch 347, minibatch 2500/2500, validation error 1.880000 %
# epoch 348, minibatch 2500/2500, validation error 1.880000 %
# epoch 349, minibatch 2500/2500, validation error 1.880000 %
# epoch 350, minibatch 2500/2500, validation error 1.880000 %
# epoch 351, minibatch 2500/2500, validation error 1.880000 %
# epoch 352, minibatch 2500/2500, validation error 1.880000 %
# epoch 353, minibatch 2500/2500, validation error 1.880000 %
# epoch 354, minibatch 2500/2500, validation error 1.880000 %
# epoch 355, minibatch 2500/2500, validation error 1.880000 %
# epoch 356, minibatch 2500/2500, validation error 1.880000 %
# epoch 357, minibatch 2500/2500, validation error 1.870000 %
#      epoch 357, minibatch 2500/2500, test error of best model 1.810000 %
# epoch 358, minibatch 2500/2500, validation error 1.870000 %
# epoch 359, minibatch 2500/2500, validation error 1.870000 %
# epoch 360, minibatch 2500/2500, validation error 1.870000 %
# epoch 361, minibatch 2500/2500, validation error 1.870000 %
# epoch 362, minibatch 2500/2500, validation error 1.870000 %
# epoch 363, minibatch 2500/2500, validation error 1.870000 %
# epoch 364, minibatch 2500/2500, validation error 1.860000 %
#      epoch 364, minibatch 2500/2500, test error of best model 1.810000 %
# epoch 365, minibatch 2500/2500, validation error 1.850000 %
#      epoch 365, minibatch 2500/2500, test error of best model 1.800000 %
# epoch 366, minibatch 2500/2500, validation error 1.850000 %
# epoch 367, minibatch 2500/2500, validation error 1.850000 %
# epoch 368, minibatch 2500/2500, validation error 1.850000 %
# epoch 369, minibatch 2500/2500, validation error 1.850000 %
# epoch 370, minibatch 2500/2500, validation error 1.860000 %
# epoch 371, minibatch 2500/2500, validation error 1.860000 %
# epoch 372, minibatch 2500/2500, validation error 1.860000 %
# epoch 373, minibatch 2500/2500, validation error 1.860000 %
# epoch 374, minibatch 2500/2500, validation error 1.860000 %
# epoch 375, minibatch 2500/2500, validation error 1.860000 %
# epoch 376, minibatch 2500/2500, validation error 1.860000 %
# epoch 377, minibatch 2500/2500, validation error 1.860000 %
# epoch 378, minibatch 2500/2500, validation error 1.860000 %
# epoch 379, minibatch 2500/2500, validation error 1.860000 %
# epoch 380, minibatch 2500/2500, validation error 1.860000 %
# epoch 381, minibatch 2500/2500, validation error 1.860000 %
# epoch 382, minibatch 2500/2500, validation error 1.860000 %
# epoch 383, minibatch 2500/2500, validation error 1.860000 %
# epoch 384, minibatch 2500/2500, validation error 1.860000 %
# epoch 385, minibatch 2500/2500, validation error 1.860000 %
# epoch 386, minibatch 2500/2500, validation error 1.860000 %
# epoch 387, minibatch 2500/2500, validation error 1.860000 %
# epoch 388, minibatch 2500/2500, validation error 1.850000 %
# epoch 389, minibatch 2500/2500, validation error 1.850000 %
# epoch 390, minibatch 2500/2500, validation error 1.850000 %
# epoch 391, minibatch 2500/2500, validation error 1.850000 %
# epoch 392, minibatch 2500/2500, validation error 1.850000 %
# epoch 393, minibatch 2500/2500, validation error 1.850000 %
# epoch 394, minibatch 2500/2500, validation error 1.850000 %
# epoch 395, minibatch 2500/2500, validation error 1.850000 %
# epoch 396, minibatch 2500/2500, validation error 1.850000 %
# epoch 397, minibatch 2500/2500, validation error 1.850000 %
# epoch 398, minibatch 2500/2500, validation error 1.850000 %
# epoch 399, minibatch 2500/2500, validation error 1.850000 %
# epoch 400, minibatch 2500/2500, validation error 1.850000 %
# epoch 401, minibatch 2500/2500, validation error 1.850000 %
# epoch 402, minibatch 2500/2500, validation error 1.850000 %
# epoch 403, minibatch 2500/2500, validation error 1.850000 %
# epoch 404, minibatch 2500/2500, validation error 1.840000 %
#      epoch 404, minibatch 2500/2500, test error of best model 1.760000 %
# epoch 405, minibatch 2500/2500, validation error 1.840000 %
# epoch 406, minibatch 2500/2500, validation error 1.840000 %
# epoch 407, minibatch 2500/2500, validation error 1.840000 %
# epoch 408, minibatch 2500/2500, validation error 1.840000 %
# epoch 409, minibatch 2500/2500, validation error 1.840000 %
# epoch 410, minibatch 2500/2500, validation error 1.840000 %
# epoch 411, minibatch 2500/2500, validation error 1.840000 %
# epoch 412, minibatch 2500/2500, validation error 1.840000 %
# epoch 413, minibatch 2500/2500, validation error 1.840000 %
# epoch 414, minibatch 2500/2500, validation error 1.840000 %
# epoch 415, minibatch 2500/2500, validation error 1.840000 %
# epoch 416, minibatch 2500/2500, validation error 1.840000 %
# epoch 417, minibatch 2500/2500, validation error 1.830000 %
#      epoch 417, minibatch 2500/2500, test error of best model 1.750000 %
# epoch 418, minibatch 2500/2500, validation error 1.830000 %
# epoch 419, minibatch 2500/2500, validation error 1.830000 %
# epoch 420, minibatch 2500/2500, validation error 1.830000 %
# epoch 421, minibatch 2500/2500, validation error 1.830000 %
# epoch 422, minibatch 2500/2500, validation error 1.830000 %
# epoch 423, minibatch 2500/2500, validation error 1.830000 %
# epoch 424, minibatch 2500/2500, validation error 1.830000 %
# epoch 425, minibatch 2500/2500, validation error 1.830000 %
# epoch 426, minibatch 2500/2500, validation error 1.830000 %
# epoch 427, minibatch 2500/2500, validation error 1.830000 %
# epoch 428, minibatch 2500/2500, validation error 1.830000 %
# epoch 429, minibatch 2500/2500, validation error 1.830000 %
# epoch 430, minibatch 2500/2500, validation error 1.820000 %
#      epoch 430, minibatch 2500/2500, test error of best model 1.750000 %
# epoch 431, minibatch 2500/2500, validation error 1.820000 %
# epoch 432, minibatch 2500/2500, validation error 1.820000 %
# epoch 433, minibatch 2500/2500, validation error 1.820000 %
# epoch 434, minibatch 2500/2500, validation error 1.820000 %
# epoch 435, minibatch 2500/2500, validation error 1.820000 %
# epoch 436, minibatch 2500/2500, validation error 1.830000 %
# epoch 437, minibatch 2500/2500, validation error 1.830000 %
# epoch 438, minibatch 2500/2500, validation error 1.830000 %
# epoch 439, minibatch 2500/2500, validation error 1.830000 %
# epoch 440, minibatch 2500/2500, validation error 1.830000 %
# epoch 441, minibatch 2500/2500, validation error 1.830000 %
# epoch 442, minibatch 2500/2500, validation error 1.820000 %
#      epoch 442, minibatch 2500/2500, test error of best model 1.770000 %
# epoch 443, minibatch 2500/2500, validation error 1.820000 %
# epoch 444, minibatch 2500/2500, validation error 1.820000 %
# epoch 445, minibatch 2500/2500, validation error 1.820000 %
# epoch 446, minibatch 2500/2500, validation error 1.820000 %
# epoch 447, minibatch 2500/2500, validation error 1.820000 %
# epoch 448, minibatch 2500/2500, validation error 1.820000 %
# epoch 449, minibatch 2500/2500, validation error 1.820000 %
# epoch 450, minibatch 2500/2500, validation error 1.810000 %
#      epoch 450, minibatch 2500/2500, test error of best model 1.770000 %
# epoch 451, minibatch 2500/2500, validation error 1.810000 %
# epoch 452, minibatch 2500/2500, validation error 1.810000 %
# epoch 453, minibatch 2500/2500, validation error 1.810000 %
# epoch 454, minibatch 2500/2500, validation error 1.810000 %
# epoch 455, minibatch 2500/2500, validation error 1.810000 %
# epoch 456, minibatch 2500/2500, validation error 1.810000 %
# epoch 457, minibatch 2500/2500, validation error 1.810000 %
# epoch 458, minibatch 2500/2500, validation error 1.810000 %
# epoch 459, minibatch 2500/2500, validation error 1.810000 %
# epoch 460, minibatch 2500/2500, validation error 1.810000 %
# epoch 461, minibatch 2500/2500, validation error 1.810000 %
# epoch 462, minibatch 2500/2500, validation error 1.810000 %
# epoch 463, minibatch 2500/2500, validation error 1.810000 %
# epoch 464, minibatch 2500/2500, validation error 1.810000 %
# epoch 465, minibatch 2500/2500, validation error 1.810000 %
# epoch 466, minibatch 2500/2500, validation error 1.810000 %
# epoch 467, minibatch 2500/2500, validation error 1.800000 %
#      epoch 467, minibatch 2500/2500, test error of best model 1.760000 %
# epoch 468, minibatch 2500/2500, validation error 1.800000 %
# epoch 469, minibatch 2500/2500, validation error 1.800000 %
# epoch 470, minibatch 2500/2500, validation error 1.800000 %
# epoch 471, minibatch 2500/2500, validation error 1.800000 %
# epoch 472, minibatch 2500/2500, validation error 1.800000 %
# epoch 473, minibatch 2500/2500, validation error 1.800000 %
# epoch 474, minibatch 2500/2500, validation error 1.800000 %
# epoch 475, minibatch 2500/2500, validation error 1.800000 %
# epoch 476, minibatch 2500/2500, validation error 1.800000 %
# epoch 477, minibatch 2500/2500, validation error 1.800000 %
# epoch 478, minibatch 2500/2500, validation error 1.800000 %
# epoch 479, minibatch 2500/2500, validation error 1.800000 %
# epoch 480, minibatch 2500/2500, validation error 1.800000 %
# epoch 481, minibatch 2500/2500, validation error 1.800000 %
# epoch 482, minibatch 2500/2500, validation error 1.800000 %
# epoch 483, minibatch 2500/2500, validation error 1.800000 %
# epoch 484, minibatch 2500/2500, validation error 1.800000 %
# epoch 485, minibatch 2500/2500, validation error 1.800000 %
# epoch 486, minibatch 2500/2500, validation error 1.800000 %
# epoch 487, minibatch 2500/2500, validation error 1.800000 %
# epoch 488, minibatch 2500/2500, validation error 1.800000 %
# epoch 489, minibatch 2500/2500, validation error 1.800000 %
# epoch 490, minibatch 2500/2500, validation error 1.800000 %
# epoch 491, minibatch 2500/2500, validation error 1.800000 %
# epoch 492, minibatch 2500/2500, validation error 1.800000 %
# epoch 493, minibatch 2500/2500, validation error 1.800000 %
# epoch 494, minibatch 2500/2500, validation error 1.800000 %
# epoch 495, minibatch 2500/2500, validation error 1.800000 %
# epoch 496, minibatch 2500/2500, validation error 1.800000 %
# epoch 497, minibatch 2500/2500, validation error 1.800000 %
# epoch 498, minibatch 2500/2500, validation error 1.800000 %
# epoch 499, minibatch 2500/2500, validation error 1.800000 %
# epoch 500, minibatch 2500/2500, validation error 1.800000 %
# epoch 501, minibatch 2500/2500, validation error 1.810000 %
# epoch 502, minibatch 2500/2500, validation error 1.810000 %
# epoch 503, minibatch 2500/2500, validation error 1.810000 %
# epoch 504, minibatch 2500/2500, validation error 1.810000 %
# epoch 505, minibatch 2500/2500, validation error 1.810000 %
# epoch 506, minibatch 2500/2500, validation error 1.810000 %
# epoch 507, minibatch 2500/2500, validation error 1.810000 %
# epoch 508, minibatch 2500/2500, validation error 1.810000 %
# epoch 509, minibatch 2500/2500, validation error 1.810000 %
# epoch 510, minibatch 2500/2500, validation error 1.810000 %
# epoch 511, minibatch 2500/2500, validation error 1.810000 %
# epoch 512, minibatch 2500/2500, validation error 1.810000 %
# epoch 513, minibatch 2500/2500, validation error 1.810000 %
# epoch 514, minibatch 2500/2500, validation error 1.810000 %
# epoch 515, minibatch 2500/2500, validation error 1.810000 %
# epoch 516, minibatch 2500/2500, validation error 1.810000 %
# epoch 517, minibatch 2500/2500, validation error 1.810000 %
# epoch 518, minibatch 2500/2500, validation error 1.810000 %
# epoch 519, minibatch 2500/2500, validation error 1.810000 %
# epoch 520, minibatch 2500/2500, validation error 1.810000 %
# epoch 521, minibatch 2500/2500, validation error 1.810000 %
# epoch 522, minibatch 2500/2500, validation error 1.810000 %
# epoch 523, minibatch 2500/2500, validation error 1.810000 %
# epoch 524, minibatch 2500/2500, validation error 1.810000 %
# epoch 525, minibatch 2500/2500, validation error 1.820000 %
# epoch 526, minibatch 2500/2500, validation error 1.820000 %
# epoch 527, minibatch 2500/2500, validation error 1.820000 %
# epoch 528, minibatch 2500/2500, validation error 1.820000 %
# epoch 529, minibatch 2500/2500, validation error 1.810000 %
# epoch 530, minibatch 2500/2500, validation error 1.810000 %
# epoch 531, minibatch 2500/2500, validation error 1.810000 %
# epoch 532, minibatch 2500/2500, validation error 1.810000 %
# epoch 533, minibatch 2500/2500, validation error 1.810000 %
# epoch 534, minibatch 2500/2500, validation error 1.810000 %
# epoch 535, minibatch 2500/2500, validation error 1.800000 %
# epoch 536, minibatch 2500/2500, validation error 1.800000 %
# epoch 537, minibatch 2500/2500, validation error 1.800000 %
# epoch 538, minibatch 2500/2500, validation error 1.800000 %
# epoch 539, minibatch 2500/2500, validation error 1.800000 %
# epoch 540, minibatch 2500/2500, validation error 1.800000 %
# epoch 541, minibatch 2500/2500, validation error 1.790000 %
#      epoch 541, minibatch 2500/2500, test error of best model 1.720000 %
# epoch 542, minibatch 2500/2500, validation error 1.790000 %
# epoch 543, minibatch 2500/2500, validation error 1.790000 %
# epoch 544, minibatch 2500/2500, validation error 1.790000 %
# epoch 545, minibatch 2500/2500, validation error 1.790000 %
# epoch 546, minibatch 2500/2500, validation error 1.790000 %
# epoch 547, minibatch 2500/2500, validation error 1.780000 %
#      epoch 547, minibatch 2500/2500, test error of best model 1.720000 %
# epoch 548, minibatch 2500/2500, validation error 1.780000 %
# epoch 549, minibatch 2500/2500, validation error 1.780000 %
# epoch 550, minibatch 2500/2500, validation error 1.780000 %
# epoch 551, minibatch 2500/2500, validation error 1.780000 %
# epoch 552, minibatch 2500/2500, validation error 1.780000 %
# epoch 553, minibatch 2500/2500, validation error 1.780000 %
# epoch 554, minibatch 2500/2500, validation error 1.770000 %
#      epoch 554, minibatch 2500/2500, test error of best model 1.710000 %
# epoch 555, minibatch 2500/2500, validation error 1.770000 %
# epoch 556, minibatch 2500/2500, validation error 1.780000 %
# epoch 557, minibatch 2500/2500, validation error 1.780000 %
# epoch 558, minibatch 2500/2500, validation error 1.780000 %
# epoch 559, minibatch 2500/2500, validation error 1.780000 %
# epoch 560, minibatch 2500/2500, validation error 1.780000 %
# epoch 561, minibatch 2500/2500, validation error 1.780000 %
# epoch 562, minibatch 2500/2500, validation error 1.770000 %
# epoch 563, minibatch 2500/2500, validation error 1.770000 %
# epoch 564, minibatch 2500/2500, validation error 1.770000 %
# epoch 565, minibatch 2500/2500, validation error 1.770000 %
# epoch 566, minibatch 2500/2500, validation error 1.770000 %
# epoch 567, minibatch 2500/2500, validation error 1.770000 %
# epoch 568, minibatch 2500/2500, validation error 1.770000 %
# epoch 569, minibatch 2500/2500, validation error 1.770000 %
# epoch 570, minibatch 2500/2500, validation error 1.780000 %
# epoch 571, minibatch 2500/2500, validation error 1.780000 %
# epoch 572, minibatch 2500/2500, validation error 1.780000 %
# epoch 573, minibatch 2500/2500, validation error 1.780000 %
# epoch 574, minibatch 2500/2500, validation error 1.780000 %
# epoch 575, minibatch 2500/2500, validation error 1.780000 %
# epoch 576, minibatch 2500/2500, validation error 1.780000 %
# epoch 577, minibatch 2500/2500, validation error 1.780000 %
# epoch 578, minibatch 2500/2500, validation error 1.780000 %
# epoch 579, minibatch 2500/2500, validation error 1.780000 %
# epoch 580, minibatch 2500/2500, validation error 1.780000 %
# epoch 581, minibatch 2500/2500, validation error 1.790000 %
# epoch 582, minibatch 2500/2500, validation error 1.790000 %
# epoch 583, minibatch 2500/2500, validation error 1.790000 %
# epoch 584, minibatch 2500/2500, validation error 1.790000 %
# epoch 585, minibatch 2500/2500, validation error 1.790000 %
# epoch 586, minibatch 2500/2500, validation error 1.790000 %
# epoch 587, minibatch 2500/2500, validation error 1.780000 %
# epoch 588, minibatch 2500/2500, validation error 1.780000 %
# epoch 589, minibatch 2500/2500, validation error 1.780000 %
# epoch 590, minibatch 2500/2500, validation error 1.780000 %
# epoch 591, minibatch 2500/2500, validation error 1.780000 %
# epoch 592, minibatch 2500/2500, validation error 1.780000 %
# epoch 593, minibatch 2500/2500, validation error 1.780000 %
# epoch 594, minibatch 2500/2500, validation error 1.780000 %
# epoch 595, minibatch 2500/2500, validation error 1.780000 %
# epoch 596, minibatch 2500/2500, validation error 1.780000 %
# epoch 597, minibatch 2500/2500, validation error 1.780000 %
# epoch 598, minibatch 2500/2500, validation error 1.780000 %
# epoch 599, minibatch 2500/2500, validation error 1.780000 %
# epoch 600, minibatch 2500/2500, validation error 1.770000 %
# epoch 601, minibatch 2500/2500, validation error 1.770000 %
# epoch 602, minibatch 2500/2500, validation error 1.760000 %
#      epoch 602, minibatch 2500/2500, test error of best model 1.680000 %
# epoch 603, minibatch 2500/2500, validation error 1.760000 %
# epoch 604, minibatch 2500/2500, validation error 1.760000 %
# epoch 605, minibatch 2500/2500, validation error 1.760000 %
# epoch 606, minibatch 2500/2500, validation error 1.760000 %
# epoch 607, minibatch 2500/2500, validation error 1.760000 %
# epoch 608, minibatch 2500/2500, validation error 1.760000 %
# epoch 609, minibatch 2500/2500, validation error 1.760000 %
# epoch 610, minibatch 2500/2500, validation error 1.760000 %
# epoch 611, minibatch 2500/2500, validation error 1.760000 %
# epoch 612, minibatch 2500/2500, validation error 1.760000 %
# epoch 613, minibatch 2500/2500, validation error 1.760000 %
# epoch 614, minibatch 2500/2500, validation error 1.760000 %
# epoch 615, minibatch 2500/2500, validation error 1.760000 %
# epoch 616, minibatch 2500/2500, validation error 1.760000 %
# epoch 617, minibatch 2500/2500, validation error 1.760000 %
# epoch 618, minibatch 2500/2500, validation error 1.760000 %
# epoch 619, minibatch 2500/2500, validation error 1.760000 %
# epoch 620, minibatch 2500/2500, validation error 1.760000 %
# epoch 621, minibatch 2500/2500, validation error 1.760000 %
# epoch 622, minibatch 2500/2500, validation error 1.760000 %
# epoch 623, minibatch 2500/2500, validation error 1.760000 %
# epoch 624, minibatch 2500/2500, validation error 1.760000 %
# epoch 625, minibatch 2500/2500, validation error 1.760000 %
# epoch 626, minibatch 2500/2500, validation error 1.760000 %
# epoch 627, minibatch 2500/2500, validation error 1.760000 %
# epoch 628, minibatch 2500/2500, validation error 1.760000 %
# epoch 629, minibatch 2500/2500, validation error 1.760000 %
# epoch 630, minibatch 2500/2500, validation error 1.760000 %
# epoch 631, minibatch 2500/2500, validation error 1.760000 %
# epoch 632, minibatch 2500/2500, validation error 1.760000 %
# epoch 633, minibatch 2500/2500, validation error 1.760000 %
# epoch 634, minibatch 2500/2500, validation error 1.760000 %
# epoch 635, minibatch 2500/2500, validation error 1.760000 %
# epoch 636, minibatch 2500/2500, validation error 1.760000 %
# epoch 637, minibatch 2500/2500, validation error 1.760000 %
# epoch 638, minibatch 2500/2500, validation error 1.760000 %
# epoch 639, minibatch 2500/2500, validation error 1.760000 %
# epoch 640, minibatch 2500/2500, validation error 1.760000 %
# epoch 641, minibatch 2500/2500, validation error 1.760000 %
# epoch 642, minibatch 2500/2500, validation error 1.760000 %
# epoch 643, minibatch 2500/2500, validation error 1.760000 %
# epoch 644, minibatch 2500/2500, validation error 1.760000 %
# epoch 645, minibatch 2500/2500, validation error 1.760000 %
# epoch 646, minibatch 2500/2500, validation error 1.760000 %
# epoch 647, minibatch 2500/2500, validation error 1.760000 %
# epoch 648, minibatch 2500/2500, validation error 1.760000 %
# epoch 649, minibatch 2500/2500, validation error 1.760000 %
# epoch 650, minibatch 2500/2500, validation error 1.760000 %
# epoch 651, minibatch 2500/2500, validation error 1.760000 %
# epoch 652, minibatch 2500/2500, validation error 1.760000 %
# epoch 653, minibatch 2500/2500, validation error 1.760000 %
# epoch 654, minibatch 2500/2500, validation error 1.760000 %
# epoch 655, minibatch 2500/2500, validation error 1.760000 %
# epoch 656, minibatch 2500/2500, validation error 1.760000 %
# epoch 657, minibatch 2500/2500, validation error 1.760000 %
# epoch 658, minibatch 2500/2500, validation error 1.760000 %
# epoch 659, minibatch 2500/2500, validation error 1.760000 %
# epoch 660, minibatch 2500/2500, validation error 1.760000 %
# epoch 661, minibatch 2500/2500, validation error 1.760000 %
# epoch 662, minibatch 2500/2500, validation error 1.760000 %
# epoch 663, minibatch 2500/2500, validation error 1.750000 %
#      epoch 663, minibatch 2500/2500, test error of best model 1.660000 %
# epoch 664, minibatch 2500/2500, validation error 1.750000 %
# epoch 665, minibatch 2500/2500, validation error 1.750000 %
# epoch 666, minibatch 2500/2500, validation error 1.750000 %
# epoch 667, minibatch 2500/2500, validation error 1.750000 %
# ...
# epoch 750, minibatch 2500/2500, validation error 1.700000 %
# epoch 751, minibatch 2500/2500, validation error 1.700000 %
# epoch 752, minibatch 2500/2500, validation error 1.700000 %
# epoch 753, minibatch 2500/2500, validation error 1.700000 %
# epoch 754, minibatch 2500/2500, validation error 1.700000 %
# epoch 755, minibatch 2500/2500, validation error 1.700000 %
# epoch 756, minibatch 2500/2500, validation error 1.700000 %
# epoch 757, minibatch 2500/2500, validation error 1.700000 %
# epoch 758, minibatch 2500/2500, validation error 1.700000 %
# epoch 759, minibatch 2500/2500, validation error 1.700000 %
# epoch 760, minibatch 2500/2500, validation error 1.700000 %
# epoch 761, minibatch 2500/2500, validation error 1.700000 %
# epoch 762, minibatch 2500/2500, validation error 1.700000 %
# epoch 763, minibatch 2500/2500, validation error 1.690000 %
#      epoch 763, minibatch 2500/2500, test error of best model 1.630000 %
# epoch 764, minibatch 2500/2500, validation error 1.690000 %
# epoch 765, minibatch 2500/2500, validation error 1.700000 %
# epoch 766, minibatch 2500/2500, validation error 1.700000 %
# epoch 767, minibatch 2500/2500, validation error 1.700000 %
# epoch 768, minibatch 2500/2500, validation error 1.700000 %
# epoch 769, minibatch 2500/2500, validation error 1.700000 %
# epoch 770, minibatch 2500/2500, validation error 1.700000 %
# epoch 771, minibatch 2500/2500, validation error 1.700000 %
# epoch 772, minibatch 2500/2500, validation error 1.700000 %
# epoch 773, minibatch 2500/2500, validation error 1.700000 %
# epoch 774, minibatch 2500/2500, validation error 1.700000 %
# epoch 775, minibatch 2500/2500, validation error 1.700000 %
# epoch 776, minibatch 2500/2500, validation error 1.700000 %
# epoch 777, minibatch 2500/2500, validation error 1.700000 %
# epoch 778, minibatch 2500/2500, validation error 1.700000 %
# epoch 779, minibatch 2500/2500, validation error 1.700000 %
# epoch 780, minibatch 2500/2500, validation error 1.700000 %
# epoch 781, minibatch 2500/2500, validation error 1.700000 %
# epoch 782, minibatch 2500/2500, validation error 1.700000 %
# epoch 783, minibatch 2500/2500, validation error 1.700000 %
# epoch 784, minibatch 2500/2500, validation error 1.700000 %
# epoch 785, minibatch 2500/2500, validation error 1.700000 %
# epoch 786, minibatch 2500/2500, validation error 1.700000 %
# epoch 787, minibatch 2500/2500, validation error 1.700000 %
# epoch 788, minibatch 2500/2500, validation error 1.700000 %
# epoch 789, minibatch 2500/2500, validation error 1.700000 %
# epoch 790, minibatch 2500/2500, validation error 1.700000 %
# epoch 791, minibatch 2500/2500, validation error 1.700000 %
# epoch 792, minibatch 2500/2500, validation error 1.700000 %
# epoch 793, minibatch 2500/2500, validation error 1.700000 %
# epoch 794, minibatch 2500/2500, validation error 1.700000 %
# epoch 795, minibatch 2500/2500, validation error 1.700000 %
# epoch 796, minibatch 2500/2500, validation error 1.700000 %
# epoch 797, minibatch 2500/2500, validation error 1.710000 %
# epoch 798, minibatch 2500/2500, validation error 1.710000 %
# epoch 799, minibatch 2500/2500, validation error 1.710000 %
# epoch 800, minibatch 2500/2500, validation error 1.710000 %
# epoch 801, minibatch 2500/2500, validation error 1.710000 %
# epoch 802, minibatch 2500/2500, validation error 1.710000 %
# epoch 803, minibatch 2500/2500, validation error 1.710000 %
# epoch 804, minibatch 2500/2500, validation error 1.710000 %
# epoch 805, minibatch 2500/2500, validation error 1.710000 %
# epoch 806, minibatch 2500/2500, validation error 1.710000 %
# epoch 807, minibatch 2500/2500, validation error 1.710000 %
# epoch 808, minibatch 2500/2500, validation error 1.710000 %
# epoch 809, minibatch 2500/2500, validation error 1.710000 %
# epoch 810, minibatch 2500/2500, validation error 1.710000 %
# epoch 811, minibatch 2500/2500, validation error 1.710000 %
# epoch 812, minibatch 2500/2500, validation error 1.710000 %
# epoch 813, minibatch 2500/2500, validation error 1.710000 %
# epoch 814, minibatch 2500/2500, validation error 1.700000 %
# epoch 815, minibatch 2500/2500, validation error 1.700000 %
# epoch 816, minibatch 2500/2500, validation error 1.690000 %
# epoch 817, minibatch 2500/2500, validation error 1.690000 %
# epoch 818, minibatch 2500/2500, validation error 1.690000 %
# epoch 819, minibatch 2500/2500, validation error 1.690000 %
# epoch 820, minibatch 2500/2500, validation error 1.680000 %
#      epoch 820, minibatch 2500/2500, test error of best model 1.650000 %
# epoch 821, minibatch 2500/2500, validation error 1.680000 %
# epoch 822, minibatch 2500/2500, validation error 1.690000 %
# epoch 823, minibatch 2500/2500, validation error 1.700000 %
# epoch 824, minibatch 2500/2500, validation error 1.700000 %
# epoch 825, minibatch 2500/2500, validation error 1.700000 %
# epoch 826, minibatch 2500/2500, validation error 1.700000 %
# epoch 827, minibatch 2500/2500, validation error 1.700000 %
# epoch 828, minibatch 2500/2500, validation error 1.700000 %
# epoch 829, minibatch 2500/2500, validation error 1.700000 %
# epoch 830, minibatch 2500/2500, validation error 1.700000 %
# epoch 831, minibatch 2500/2500, validation error 1.700000 %
# epoch 832, minibatch 2500/2500, validation error 1.700000 %
# epoch 833, minibatch 2500/2500, validation error 1.700000 %
# epoch 834, minibatch 2500/2500, validation error 1.700000 %
# epoch 835, minibatch 2500/2500, validation error 1.700000 %
# epoch 836, minibatch 2500/2500, validation error 1.690000 %
# epoch 837, minibatch 2500/2500, validation error 1.690000 %
# epoch 838, minibatch 2500/2500, validation error 1.690000 %
# epoch 839, minibatch 2500/2500, validation error 1.690000 %
# epoch 840, minibatch 2500/2500, validation error 1.690000 %
# epoch 841, minibatch 2500/2500, validation error 1.690000 %
# epoch 842, minibatch 2500/2500, validation error 1.690000 %
# epoch 843, minibatch 2500/2500, validation error 1.690000 %
# epoch 844, minibatch 2500/2500, validation error 1.690000 %
# epoch 845, minibatch 2500/2500, validation error 1.690000 %
# epoch 846, minibatch 2500/2500, validation error 1.690000 %
# epoch 847, minibatch 2500/2500, validation error 1.690000 %
# epoch 848, minibatch 2500/2500, validation error 1.690000 %
# epoch 849, minibatch 2500/2500, validation error 1.690000 %
# epoch 850, minibatch 2500/2500, validation error 1.690000 %
# epoch 851, minibatch 2500/2500, validation error 1.690000 %
# epoch 852, minibatch 2500/2500, validation error 1.690000 %
# epoch 853, minibatch 2500/2500, validation error 1.690000 %
# epoch 854, minibatch 2500/2500, validation error 1.690000 %
# epoch 855, minibatch 2500/2500, validation error 1.690000 %
# epoch 856, minibatch 2500/2500, validation error 1.690000 %
# epoch 857, minibatch 2500/2500, validation error 1.690000 %
# epoch 858, minibatch 2500/2500, validation error 1.690000 %
# epoch 859, minibatch 2500/2500, validation error 1.690000 %
# epoch 860, minibatch 2500/2500, validation error 1.690000 %
# epoch 861, minibatch 2500/2500, validation error 1.690000 %
# epoch 862, minibatch 2500/2500, validation error 1.690000 %
# epoch 863, minibatch 2500/2500, validation error 1.690000 %
# epoch 864, minibatch 2500/2500, validation error 1.690000 %
# epoch 865, minibatch 2500/2500, validation error 1.690000 %
# epoch 866, minibatch 2500/2500, validation error 1.690000 %
# epoch 867, minibatch 2500/2500, validation error 1.690000 %
# epoch 868, minibatch 2500/2500, validation error 1.690000 %
# epoch 869, minibatch 2500/2500, validation error 1.690000 %
# epoch 870, minibatch 2500/2500, validation error 1.690000 %
# epoch 871, minibatch 2500/2500, validation error 1.690000 %
# epoch 872, minibatch 2500/2500, validation error 1.690000 %
# epoch 873, minibatch 2500/2500, validation error 1.700000 %
# epoch 874, minibatch 2500/2500, validation error 1.700000 %
# epoch 875, minibatch 2500/2500, validation error 1.700000 %
# epoch 876, minibatch 2500/2500, validation error 1.700000 %
# epoch 877, minibatch 2500/2500, validation error 1.700000 %
# epoch 878, minibatch 2500/2500, validation error 1.700000 %
# epoch 879, minibatch 2500/2500, validation error 1.700000 %
# epoch 880, minibatch 2500/2500, validation error 1.700000 %
# epoch 881, minibatch 2500/2500, validation error 1.700000 %
# epoch 882, minibatch 2500/2500, validation error 1.700000 %
# epoch 883, minibatch 2500/2500, validation error 1.700000 %
# epoch 884, minibatch 2500/2500, validation error 1.700000 %
# epoch 885, minibatch 2500/2500, validation error 1.700000 %
# epoch 886, minibatch 2500/2500, validation error 1.700000 %
# epoch 887, minibatch 2500/2500, validation error 1.700000 %
# epoch 888, minibatch 2500/2500, validation error 1.700000 %
# epoch 889, minibatch 2500/2500, validation error 1.700000 %
# epoch 890, minibatch 2500/2500, validation error 1.700000 %
# epoch 891, minibatch 2500/2500, validation error 1.700000 %
# epoch 892, minibatch 2500/2500, validation error 1.700000 %
# epoch 893, minibatch 2500/2500, validation error 1.700000 %
# epoch 894, minibatch 2500/2500, validation error 1.700000 %
# epoch 895, minibatch 2500/2500, validation error 1.700000 %
# epoch 896, minibatch 2500/2500, validation error 1.700000 %
# epoch 897, minibatch 2500/2500, validation error 1.700000 %
# epoch 898, minibatch 2500/2500, validation error 1.700000 %
# epoch 899, minibatch 2500/2500, validation error 1.700000 %
# epoch 900, minibatch 2500/2500, validation error 1.700000 %
# epoch 901, minibatch 2500/2500, validation error 1.700000 %
# epoch 902, minibatch 2500/2500, validation error 1.700000 %
# epoch 903, minibatch 2500/2500, validation error 1.700000 %
# epoch 904, minibatch 2500/2500, validation error 1.700000 %
# epoch 905, minibatch 2500/2500, validation error 1.700000 %
# epoch 906, minibatch 2500/2500, validation error 1.700000 %
# epoch 907, minibatch 2500/2500, validation error 1.700000 %
# epoch 908, minibatch 2500/2500, validation error 1.700000 %
# epoch 909, minibatch 2500/2500, validation error 1.700000 %
# epoch 910, minibatch 2500/2500, validation error 1.700000 %
# epoch 911, minibatch 2500/2500, validation error 1.700000 %
# epoch 912, minibatch 2500/2500, validation error 1.700000 %
# epoch 913, minibatch 2500/2500, validation error 1.700000 %
# epoch 914, minibatch 2500/2500, validation error 1.700000 %
# epoch 915, minibatch 2500/2500, validation error 1.700000 %
# epoch 916, minibatch 2500/2500, validation error 1.700000 %
# epoch 917, minibatch 2500/2500, validation error 1.700000 %
# epoch 918, minibatch 2500/2500, validation error 1.700000 %
# epoch 919, minibatch 2500/2500, validation error 1.700000 %
# epoch 920, minibatch 2500/2500, validation error 1.700000 %
# epoch 921, minibatch 2500/2500, validation error 1.700000 %
# epoch 922, minibatch 2500/2500, validation error 1.700000 %
# epoch 923, minibatch 2500/2500, validation error 1.700000 %
# epoch 924, minibatch 2500/2500, validation error 1.700000 %
# epoch 925, minibatch 2500/2500, validation error 1.700000 %
# epoch 926, minibatch 2500/2500, validation error 1.700000 %
# epoch 927, minibatch 2500/2500, validation error 1.700000 %
# epoch 928, minibatch 2500/2500, validation error 1.700000 %
# epoch 929, minibatch 2500/2500, validation error 1.700000 %
# epoch 930, minibatch 2500/2500, validation error 1.700000 %
# epoch 931, minibatch 2500/2500, validation error 1.700000 %
# epoch 932, minibatch 2500/2500, validation error 1.710000 %
# epoch 933, minibatch 2500/2500, validation error 1.710000 %
# epoch 934, minibatch 2500/2500, validation error 1.710000 %
# epoch 935, minibatch 2500/2500, validation error 1.710000 %
# epoch 936, minibatch 2500/2500, validation error 1.710000 %
# epoch 937, minibatch 2500/2500, validation error 1.710000 %
# epoch 938, minibatch 2500/2500, validation error 1.710000 %
# epoch 939, minibatch 2500/2500, validation error 1.710000 %
# epoch 940, minibatch 2500/2500, validation error 1.700000 %
# epoch 941, minibatch 2500/2500, validation error 1.700000 %
# epoch 942, minibatch 2500/2500, validation error 1.690000 %
# epoch 943, minibatch 2500/2500, validation error 1.690000 %
# epoch 944, minibatch 2500/2500, validation error 1.690000 %
# epoch 945, minibatch 2500/2500, validation error 1.690000 %
# epoch 946, minibatch 2500/2500, validation error 1.690000 %
# epoch 947, minibatch 2500/2500, validation error 1.690000 %
# epoch 948, minibatch 2500/2500, validation error 1.690000 %
# epoch 949, minibatch 2500/2500, validation error 1.690000 %
# epoch 950, minibatch 2500/2500, validation error 1.690000 %
# epoch 951, minibatch 2500/2500, validation error 1.690000 %
# epoch 952, minibatch 2500/2500, validation error 1.690000 %
# epoch 953, minibatch 2500/2500, validation error 1.690000 %
# epoch 954, minibatch 2500/2500, validation error 1.690000 %
# epoch 955, minibatch 2500/2500, validation error 1.690000 %
# epoch 956, minibatch 2500/2500, validation error 1.690000 %
# epoch 957, minibatch 2500/2500, validation error 1.690000 %
# epoch 958, minibatch 2500/2500, validation error 1.690000 %
# epoch 959, minibatch 2500/2500, validation error 1.690000 %
# epoch 960, minibatch 2500/2500, validation error 1.690000 %
# epoch 961, minibatch 2500/2500, validation error 1.690000 %
# epoch 962, minibatch 2500/2500, validation error 1.690000 %
# epoch 963, minibatch 2500/2500, validation error 1.690000 %
# epoch 964, minibatch 2500/2500, validation error 1.690000 %
# epoch 965, minibatch 2500/2500, validation error 1.690000 %
# epoch 966, minibatch 2500/2500, validation error 1.690000 %
# epoch 967, minibatch 2500/2500, validation error 1.690000 %
# epoch 968, minibatch 2500/2500, validation error 1.690000 %
# epoch 969, minibatch 2500/2500, validation error 1.690000 %
# epoch 970, minibatch 2500/2500, validation error 1.690000 %
# epoch 971, minibatch 2500/2500, validation error 1.690000 %
# epoch 972, minibatch 2500/2500, validation error 1.690000 %
# epoch 973, minibatch 2500/2500, validation error 1.690000 %
# epoch 974, minibatch 2500/2500, validation error 1.690000 %
# epoch 975, minibatch 2500/2500, validation error 1.690000 %
# epoch 976, minibatch 2500/2500, validation error 1.690000 %
# epoch 977, minibatch 2500/2500, validation error 1.690000 %
# epoch 978, minibatch 2500/2500, validation error 1.690000 %
# epoch 979, minibatch 2500/2500, validation error 1.690000 %
# epoch 980, minibatch 2500/2500, validation error 1.690000 %
# epoch 981, minibatch 2500/2500, validation error 1.690000 %
# epoch 982, minibatch 2500/2500, validation error 1.690000 %
# epoch 983, minibatch 2500/2500, validation error 1.690000 %
# epoch 984, minibatch 2500/2500, validation error 1.690000 %
# epoch 985, minibatch 2500/2500, validation error 1.690000 %
# epoch 986, minibatch 2500/2500, validation error 1.690000 %
# epoch 987, minibatch 2500/2500, validation error 1.690000 %
# epoch 988, minibatch 2500/2500, validation error 1.690000 %
# epoch 989, minibatch 2500/2500, validation error 1.700000 %
# epoch 990, minibatch 2500/2500, validation error 1.700000 %
# epoch 991, minibatch 2500/2500, validation error 1.700000 %
# epoch 992, minibatch 2500/2500, validation error 1.700000 %
# epoch 993, minibatch 2500/2500, validation error 1.700000 %
# epoch 994, minibatch 2500/2500, validation error 1.700000 %
# epoch 995, minibatch 2500/2500, validation error 1.700000 %
# epoch 996, minibatch 2500/2500, validation error 1.700000 %
# epoch 997, minibatch 2500/2500, validation error 1.700000 %
# epoch 998, minibatch 2500/2500, validation error 1.700000 %
# epoch 999, minibatch 2500/2500, validation error 1.700000 %
# epoch 1000, minibatch 2500/2500, validation error 1.700000 %
# Optimization complete. Best validation score of 1.680000 % obtained at iteration 2050000, with test performance 1.650000 %
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-3204ab7c2fef> in <module>()
# ----> 1 test_mlp()
#
# <ipython-input-17-3bff015873c3> in test_mlp(learning_rate, L1_reg, L2_reg, n_epochs, dataset, batch_size, n_hidden)
#     202            'obtained at iteration %i, with test performance %f %%') %
#     203           (best_validation_loss * 100., best_iter + 1, test_score * 100.))
# --> 204     print('The code for this function ran for %.2fm' % (end_time - start_time) / 60.)
#
# TypeError: unsupported operand type(s) for /: 'str' and 'float'

# %% [markdown]
# Classifying MNIST digits get best test error 1.65% by using Multi-Layer Perceptron, but training the model spend nearly six hours in my laptop on CPU.
#
# In my exercise, classifying MNIST digits using Logistic Regression, have best test error 7.5%, but training the model only spend 20.4 second in the same computer on CPU.
#
# Tiny improve in test error, need more capacity or knoweledge and time.
#
# No free lunch.

# %% [markdown]
# # Reference:
#
# - http://deeplearning.net/tutorial/mlp.html#mlp
# - http://www.learnartificialneuralnetworks.com/introduction-to-neural-networks.html
# - http://www.cnblogs.com/xubenben/p/3860285.html
# - http://www.cnblogs.com/wentingtu/archive/2012/06/05/2536425.html
# - http://blog.sina.com.cn/s/blog_88f0497e0102v79c.html
# - http://licstar.net/archives/328
